# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
import json
import math
import os

import cv2
from PIL import Image
import numpy as np
from keras import layers
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg16 import VGG16
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D, Average, Input, Concatenate, GlobalMaxPooling2D,BatchNormalization
from keras.applications import ResNet50,MobileNet, DenseNet201, InceptionV3, NASNetLarge, InceptionResNetV2, NASNetMobile
from keras.applications.xception import Xception
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.optimizers import Adam
from keras.models import Model
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools


# %matplotlib inline

# %%
#Transfer 'jpg' images to an array IMG
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".png":
            img = read(PATH)
           
            img = cv2.resize(img, (RESIZE,RESIZE))
           
            IMG.append(np.array(img))
    return IMG

# %%
benign_train = np.array(Dataset_loader('/content/drive/My Drive/BreakHish Final Dataset/train/benign',224))
malign_train = np.array(Dataset_loader('/content/drive/My Drive/BreakHish Final Dataset/train/malignant',224))
benign_test = np.array(Dataset_loader('/content/drive/My Drive/BreakHish Final Dataset/test/benign',224))
malign_test = np.array(Dataset_loader('/content/drive/My Drive/BreakHish Final Dataset/test/malignant',224))

# %%
print(len(benign_train))

# %%
# Create labels
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))

# %%
# Merge data 
X_train = np.concatenate((benign_train, malign_train), axis = 0)
Y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
X_test = np.concatenate((benign_test, malign_test), axis = 0)
Y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)

# %%
# Shuffle train data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = Y_train[s]

# Shuffle test data
s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = Y_test[s]

# %%
# To categorical
Y_train = to_categorical(Y_train, num_classes= 2)
Y_test = to_categorical(Y_test, num_classes= 2)

# %%
x_train, x_val, y_train, y_val = train_test_split(
    X_train, Y_train, 
    test_size=0.2, 
    random_state=11
)

# %%
# # Display first 15 images of moles, and how they are classified
w=60
h=40
fig=plt.figure(figsize=(10,10))
columns = 4
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(Y_train[i]) == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(x_train[i], interpolation='nearest')
plt.show()

# %%
BATCH_SIZE = 32

# Using original generator
train_generator = ImageDataGenerator(
        zoom_range=2,  # set range for random zoom
        rotation_range = 90,
        shear_range = 0.5,
        width_shift_range=0.4,
        height_shift_range=0.4,
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True  # randomly flip images
    )

# %%
IMAGE_SIZE=224
# Model
input_shape = (IMAGE_SIZE, IMAGE_SIZE, 3)
inputs = Input(input_shape)
 
#dennet   = DenseNet201(include_top=False, input_shape=input_shape)(inputs)
#nas      = NASNetMobile(include_top=False, input_shape=input_shape)(inputs)
vgg      = VGG16(include_top=False, input_shape=input_shape)(inputs)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step

# %%
outputs = GlobalAveragePooling2D()(vgg)
outputs = Dropout(0.4)(outputs)
outputs = BatchNormalization()(outputs) 
outputs = Dense(128,activation='relu')(outputs) 
outputs = Dropout(0.2)(outputs)
outputs = BatchNormalization()(outputs) 
outputs = Dense(2, activation='softmax')(outputs)

model = Model(inputs, outputs)
model.compile(optimizer=Adam(lr=0.0001, decay=0.00001),
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# dense (Dense)                (None, 128)               65664
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 14,783,170
# Trainable params: 14,781,890
# Non-trainable params: 1,280
# _________________________________________________________________

# %%
# Learning Rate Reducer
learn_control = ReduceLROnPlateau(monitor='val_acc', patience=5,
                                  verbose=1,factor=0.2, min_lr=1e-7)

# Checkpoint
filepath="/content/drive/My Drive/best_vgg.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %%
history = model.fit_generator(
    train_generator.flow(x_train, y_train, batch_size=BATCH_SIZE),
    steps_per_epoch=x_train.shape[0] / BATCH_SIZE,
    epochs=50,
    validation_data=(x_val, y_val),
    callbacks=[learn_control, checkpoint]
)
# Out:
# WARNING:tensorflow:From <ipython-input-14-6994e6891fd9>:6: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
#   2/193 [..............................] - ETA: 36s - loss: 1.0710 - accuracy: 0.5000WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1083s vs `on_train_batch_end` time: 0.2722s). Check your callbacks.
# 194/193 [==============================] - ETA: 0s - loss: 0.8384 - accuracy: 0.5996WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 105s 544ms/step - loss: 0.8384 - accuracy: 0.5996 - val_loss: 0.6208 - val_accuracy: 0.7698
# Epoch 2/50
# 194/193 [==============================] - ETA: 0s - loss: 0.6030 - accuracy: 0.7325WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 104s 536ms/step - loss: 0.6030 - accuracy: 0.7325 - val_loss: 0.3962 - val_accuracy: 0.8652
# Epoch 3/50
# 194/193 [==============================] - ETA: 0s - loss: 0.5129 - accuracy: 0.7909WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 104s 537ms/step - loss: 0.5129 - accuracy: 0.7909 - val_loss: 0.4121 - val_accuracy: 0.8736
# Epoch 4/50
# 194/193 [==============================] - ETA: 0s - loss: 0.5590 - accuracy: 0.7636WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 105s 543ms/step - loss: 0.5590 - accuracy: 0.7636 - val_loss: 2.2414 - val_accuracy: 0.3075
# Epoch 5/50
# 194/193 [==============================] - ETA: 0s - loss: 0.5976 - accuracy: 0.7585WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 104s 538ms/step - loss: 0.5976 - accuracy: 0.7585 - val_loss: 0.4365 - val_accuracy: 0.8169
# Epoch 6/50
# 194/193 [==============================] - ETA: 0s - loss: 0.4699 - accuracy: 0.8209WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 104s 536ms/step - loss: 0.4699 - accuracy: 0.8209 - val_loss: 0.3742 - val_accuracy: 0.8627
# Epoch 7/50
# 194/193 [==============================] - ETA: 0s - loss: 0.4371 - accuracy: 0.8444WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 104s 539ms/step - loss: 0.4371 - accuracy: 0.8444 - val_loss: 0.3664 - val_accuracy: 0.8646
# Epoch 8/50
# 194/193 [==============================] - ETA: 0s - loss: 0.3824 - accuracy: 0.8578WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 104s 537ms/step - loss: 0.3824 - accuracy: 0.8578 - val_loss: 0.3928 - val_accuracy: 0.8414
# Epoch 9/50
# 194/193 [==============================] - ETA: 0s - loss: 0.4252 - accuracy: 0.8481WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 105s 543ms/step - loss: 0.4252 - accuracy: 0.8481 - val_loss: 0.8412 - val_accuracy: 0.7827
# Epoch 10/50
# 194/193 [==============================] - ETA: 0s - loss: 0.4105 - accuracy: 0.8542WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 105s 543ms/step - loss: 0.4105 - accuracy: 0.8542 - val_loss: 0.6928 - val_accuracy: 0.6596
# Epoch 11/50
# 194/193 [==============================] - ETA: 0s - loss: 0.4108 - accuracy: 0.8496WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 105s 542ms/step - loss: 0.4108 - accuracy: 0.8496 - val_loss: 0.2796 - val_accuracy: 0.8994
# Epoch 12/50
# 194/193 [==============================] - ETA: 0s - loss: 0.3721 - accuracy: 0.8634WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 105s 544ms/step - loss: 0.3721 - accuracy: 0.8634 - val_loss: 0.3184 - val_accuracy: 0.8891
# Epoch 13/50
# 194/193 [==============================] - ETA: 0s - loss: 0.3540 - accuracy: 0.8684WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 106s 545ms/step - loss: 0.3540 - accuracy: 0.8684 - val_loss: 0.2994 - val_accuracy: 0.8968
# Epoch 14/50
# 194/193 [==============================] - ETA: 0s - loss: 0.3490 - accuracy: 0.8721WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 106s 547ms/step - loss: 0.3490 - accuracy: 0.8721 - val_loss: 0.2969 - val_accuracy: 0.8904
# Epoch 15/50
# 194/193 [==============================] - ETA: 0s - loss: 0.3271 - accuracy: 0.8760WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 105s 543ms/step - loss: 0.3271 - accuracy: 0.8760 - val_loss: 0.2634 - val_accuracy: 0.8962
# Epoch 16/50
# 194/193 [==============================] - ETA: 0s - loss: 0.3199 - accuracy: 0.8755WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 105s 542ms/step - loss: 0.3199 - accuracy: 0.8755 - val_loss: 0.2320 - val_accuracy: 0.9091
# Epoch 17/50
# 194/193 [==============================] - ETA: 0s - loss: 0.3064 - accuracy: 0.8854WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 105s 539ms/step - loss: 0.3064 - accuracy: 0.8854 - val_loss: 0.2829 - val_accuracy: 0.8833
# Epoch 18/50
# 194/193 [==============================] - ETA: 0s - loss: 0.3018 - accuracy: 0.8836WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 105s 543ms/step - loss: 0.3018 - accuracy: 0.8836 - val_loss: 0.2450 - val_accuracy: 0.9026
# Epoch 19/50
# 194/193 [==============================] - ETA: 0s - loss: 0.3117 - accuracy: 0.8808WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 103s 529ms/step - loss: 0.3117 - accuracy: 0.8808 - val_loss: 0.2393 - val_accuracy: 0.9084
# Epoch 20/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2982 - accuracy: 0.8857WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 104s 536ms/step - loss: 0.2982 - accuracy: 0.8857 - val_loss: 0.2183 - val_accuracy: 0.9117
# Epoch 21/50
# 194/193 [==============================] - ETA: 0s - loss: 0.3062 - accuracy: 0.8799WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 105s 542ms/step - loss: 0.3062 - accuracy: 0.8799 - val_loss: 0.2140 - val_accuracy: 0.9168
# Epoch 22/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2821 - accuracy: 0.8894WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 106s 544ms/step - loss: 0.2821 - accuracy: 0.8894 - val_loss: 0.3309 - val_accuracy: 0.8285
# Epoch 23/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2791 - accuracy: 0.8920WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 105s 543ms/step - loss: 0.2791 - accuracy: 0.8920 - val_loss: 0.2305 - val_accuracy: 0.9078
# Epoch 24/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2740 - accuracy: 0.8970WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 106s 545ms/step - loss: 0.2740 - accuracy: 0.8970 - val_loss: 0.1915 - val_accuracy: 0.9149
# Epoch 25/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2808 - accuracy: 0.8929WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 106s 544ms/step - loss: 0.2808 - accuracy: 0.8929 - val_loss: 0.2069 - val_accuracy: 0.9188
# Epoch 26/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2782 - accuracy: 0.8955WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 103s 530ms/step - loss: 0.2782 - accuracy: 0.8955 - val_loss: 0.2119 - val_accuracy: 0.9149
# Epoch 27/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2738 - accuracy: 0.8965WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 102s 524ms/step - loss: 0.2738 - accuracy: 0.8965 - val_loss: 0.1987 - val_accuracy: 0.9168
# Epoch 28/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2563 - accuracy: 0.8946WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 100s 518ms/step - loss: 0.2563 - accuracy: 0.8946 - val_loss: 0.2084 - val_accuracy: 0.9149
# Epoch 29/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2657 - accuracy: 0.8997WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 100s 517ms/step - loss: 0.2657 - accuracy: 0.8997 - val_loss: 0.2208 - val_accuracy: 0.9149
# Epoch 30/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2609 - accuracy: 0.9016WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 100s 517ms/step - loss: 0.2609 - accuracy: 0.9016 - val_loss: 0.1909 - val_accuracy: 0.9162
# Epoch 31/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2564 - accuracy: 0.9013WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 101s 520ms/step - loss: 0.2564 - accuracy: 0.9013 - val_loss: 0.2734 - val_accuracy: 0.8872
# Epoch 32/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2477 - accuracy: 0.9060WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 101s 523ms/step - loss: 0.2477 - accuracy: 0.9060 - val_loss: 0.2409 - val_accuracy: 0.8904
# Epoch 33/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2574 - accuracy: 0.9036WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 101s 519ms/step - loss: 0.2574 - accuracy: 0.9036 - val_loss: 0.2524 - val_accuracy: 0.8833
# Epoch 34/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2447 - accuracy: 0.9065WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 100s 517ms/step - loss: 0.2447 - accuracy: 0.9065 - val_loss: 0.1895 - val_accuracy: 0.9142
# Epoch 35/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2409 - accuracy: 0.9062WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 100s 518ms/step - loss: 0.2409 - accuracy: 0.9062 - val_loss: 0.2535 - val_accuracy: 0.9020
# Epoch 36/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2399 - accuracy: 0.9091WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 100s 516ms/step - loss: 0.2399 - accuracy: 0.9091 - val_loss: 0.3405 - val_accuracy: 0.8749
# Epoch 37/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2428 - accuracy: 0.9094WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 100s 516ms/step - loss: 0.2428 - accuracy: 0.9094 - val_loss: 0.1797 - val_accuracy: 0.9252
# Epoch 38/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2396 - accuracy: 0.9029WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 100s 515ms/step - loss: 0.2396 - accuracy: 0.9029 - val_loss: 0.1856 - val_accuracy: 0.9213
# Epoch 39/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2392 - accuracy: 0.9074WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 101s 520ms/step - loss: 0.2392 - accuracy: 0.9074 - val_loss: 0.2512 - val_accuracy: 0.8968
# Epoch 40/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2456 - accuracy: 0.9081WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 101s 519ms/step - loss: 0.2456 - accuracy: 0.9081 - val_loss: 0.1728 - val_accuracy: 0.9317
# Epoch 41/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2330 - accuracy: 0.9071WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 100s 517ms/step - loss: 0.2330 - accuracy: 0.9071 - val_loss: 0.2773 - val_accuracy: 0.9033
# Epoch 42/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2347 - accuracy: 0.9074WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 100s 514ms/step - loss: 0.2347 - accuracy: 0.9074 - val_loss: 0.2219 - val_accuracy: 0.9123
# Epoch 43/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2194 - accuracy: 0.9136WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 100s 514ms/step - loss: 0.2194 - accuracy: 0.9136 - val_loss: 0.2080 - val_accuracy: 0.9194
# Epoch 44/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2186 - accuracy: 0.9171WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 100s 517ms/step - loss: 0.2186 - accuracy: 0.9171 - val_loss: 0.2016 - val_accuracy: 0.9233
# Epoch 45/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2173 - accuracy: 0.9170WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 101s 519ms/step - loss: 0.2173 - accuracy: 0.9170 - val_loss: 0.1985 - val_accuracy: 0.9130
# Epoch 46/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2186 - accuracy: 0.9176WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 101s 523ms/step - loss: 0.2186 - accuracy: 0.9176 - val_loss: 0.3747 - val_accuracy: 0.8975
# Epoch 47/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2312 - accuracy: 0.9100WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 102s 528ms/step - loss: 0.2312 - accuracy: 0.9100 - val_loss: 0.3028 - val_accuracy: 0.8846
# Epoch 48/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2221 - accuracy: 0.9160WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 103s 530ms/step - loss: 0.2221 - accuracy: 0.9160 - val_loss: 0.2233 - val_accuracy: 0.9091
# Epoch 49/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2323 - accuracy: 0.9107WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 104s 536ms/step - loss: 0.2323 - accuracy: 0.9107 - val_loss: 1.2597 - val_accuracy: 0.6209
# Epoch 50/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2262 - accuracy: 0.9099WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 104s 535ms/step - loss: 0.2262 - accuracy: 0.9099 - val_loss: 0.1675 - val_accuracy: 0.9213

# %%
Y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))

cm_plot_label =['Benign', 'Malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Benign vs Malignant')
# Out:
# Confusion matrix, without normalization
# [[71  4]
#  [ 8 77]]

# %%
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
roc_log = roc_auc_score(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))
false_positive_rate, true_positive_rate, threshold = roc_curve(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))
area_under_curve = auc(false_positive_rate, true_positive_rate)

plt.plot([0, 1], [0, 1], 'r--')
plt.plot(false_positive_rate, true_positive_rate, label='AUC = {:.3f}'.format(area_under_curve))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
#plt.savefig(ROC_PLOT_FILE, bbox_inches='tight')
plt.close()

# %%
i=0
prop_class=[]
mis_class=[]

for i in range(len(Y_test)):
    if(np.argmax(Y_test[i])==np.argmax(Y_pred[i])):
        prop_class.append(i)
    if(len(prop_class)==8):
        break

i=0
for i in range(len(Y_test)):
    if(not np.argmax(Y_test[i])==np.argmax(Y_pred[i])):
        mis_class.append(i)
    if(len(mis_class)==8):
        break

# # Display first 8 images of benign
w=60
h=40
fig=plt.figure(figsize=(18, 10))
columns = 4
rows = 2

def Transfername(namecode):
    if namecode==0:
        return "Benign"
    else:
        return "Malignant"
    
for i in range(len(prop_class)):
    ax = fig.add_subplot(rows, columns, i+1)
    ax.set_title("Predicted result:"+ Transfername(np.argmax(Y_pred[prop_class[i]]))
                       +"\n"+"Actual result: "+ Transfername(np.argmax(Y_test[prop_class[i]])))
    plt.imshow(X_test[prop_class[i]], interpolation='nearest')
plt.show()

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('VGG16 Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,51))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.grid()
ax1.set_xticks(np.arange(1, 51, 4))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.grid()
ax2.set_xticks(np.arange(1, 51, 4))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
pred=model.predict(X_test)
Y_pred = np.argmax(pred, 1)
y_test=np.argmax(Y_test,1)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print('Classification Report')
target_names = ['Benign', 'Malignant']
print(classification_report(y_test, Y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#       Benign       0.90      0.95      0.92        75
#    Malignant       0.95      0.91      0.93        85
#
#     accuracy                           0.93       160
#    macro avg       0.92      0.93      0.92       160
# weighted avg       0.93      0.93      0.93       160
