# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
import json
import math
import os

import cv2
from PIL import Image
import numpy as np
from keras import layers
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg16 import VGG16
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D, Average, Input, Concatenate, GlobalMaxPooling2D,BatchNormalization
from keras.applications import ResNet50,MobileNet, DenseNet201, InceptionV3, NASNetLarge, InceptionResNetV2, NASNetMobile
from keras.applications.xception import Xception
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.optimizers import Adam
from keras.models import Model
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools


# %matplotlib inline

# %%
#Transfer 'jpg' images to an array IMG
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".png":
            img = read(PATH)
           
            img = cv2.resize(img, (RESIZE,RESIZE))
           
            IMG.append(np.array(img))
    return IMG

# %%
benign_train   =   np.array(Dataset_loader('/content/drive/My Drive/ICIAR2018-2/train/Benign',224))
insitu_train   =   np.array(Dataset_loader('/content/drive/My Drive/ICIAR2018-2/train/InSitu',224))
invasive_train =   np.array(Dataset_loader('/content/drive/My Drive/ICIAR2018-2/train/Invasive',224))
normal_train   =   np.array(Dataset_loader('/content/drive/My Drive/ICIAR2018-2/train/Normal',224))

benign_test    =   np.array(Dataset_loader('/content/drive/My Drive/ICIAR2018-2/test/Benign',224))
insitu_test    =   np.array(Dataset_loader('/content/drive/My Drive/ICIAR2018-2/test/InSitu',224))
invasive_test  =   np.array(Dataset_loader('/content/drive/My Drive/ICIAR2018-2/test/Invasive',224))
normal_test    =   np.array(Dataset_loader('/content/drive/My Drive/ICIAR2018-2/test/Normal',224))
# Out:
# 100%|██████████| 90/90 [01:28<00:00,  1.01it/s]
# 100%|██████████| 90/90 [01:30<00:00,  1.00s/it]
# 100%|██████████| 90/90 [01:40<00:00,  1.11s/it]
# 100%|██████████| 90/90 [01:37<00:00,  1.09s/it]
# 100%|██████████| 10/10 [00:10<00:00,  1.08s/it]
# 100%|██████████| 10/10 [00:12<00:00,  1.28s/it]
# 100%|██████████| 10/10 [00:13<00:00,  1.33s/it]
# 100%|██████████| 10/10 [00:09<00:00,  1.05it/s]

# %%
# Create labels
benign_train_label   = np.full(len(benign_train),0)
insitu_train_label   = np.full(len(insitu_train),1)
invasive_train_label = np.full(len(invasive_train),2)
normal_train_label   = np.full(len(normal_train),3)

benign_test_label   = np.full(len(benign_test),0)
insitu_test_label   = np.full(len(insitu_test),1)
invasive_test_label = np.full(len(invasive_test),2)
normal_test_label   = np.full(len(normal_test),3)

# %%
# Merge data 
X_train = np.concatenate((benign_train, insitu_train, invasive_train, normal_train), axis = 0)
Y_train = np.concatenate((benign_train_label, insitu_train_label, invasive_train_label, normal_train_label), axis = 0)
X_test = np.concatenate((benign_test, insitu_test, invasive_test, normal_test), axis = 0)
Y_test = np.concatenate((benign_test_label, insitu_test_label, invasive_test_label, normal_test_label), axis = 0)

# %%
# Shuffle train data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = Y_train[s]

# Shuffle test data
s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = Y_test[s]

# %%
# To categorical
Y_train = to_categorical(Y_train, num_classes= 4)
Y_test = to_categorical(Y_test, num_classes= 4)

# %%
x_train, x_val, y_train, y_val = train_test_split(
    X_train, Y_train, 
    test_size=0.2, 
    random_state=11
)

# %%
BATCH_SIZE = 32

# Using original generator
train_generator = ImageDataGenerator(
        zoom_range=2,  # set range for random zoom
        rotation_range = 90,
        shear_range = 0.5,
        width_shift_range=0.4,
        height_shift_range=0.4,
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True  # randomly flip images
    )

# %%
IMAGE_SIZE=224
# Model
input_shape = (IMAGE_SIZE, IMAGE_SIZE, 3)
inputs = Input(input_shape)
 
dennet   = DenseNet201(include_top=False, input_shape=input_shape)(inputs)
#nas      = NASNetMobile(include_top=False, input_shape=input_shape)(inputs)
#vgg      = VGG16(include_top=False, input_shape=input_shape)(inputs)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 0s 0us/step

# %%
outputs = GlobalAveragePooling2D()(dennet)
outputs = Dropout(0.4)(outputs)
outputs = BatchNormalization()(outputs) 
outputs = Dense(128,activation='relu')(outputs) 
outputs = Dropout(0.2)(outputs)
outputs = BatchNormalization()(outputs) 
outputs = Dense(4, activation='softmax')(outputs)

model = Model(inputs, outputs)
model.compile(optimizer=Adam(lr=0.0001, decay=0.00001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# densenet201 (Functional)     (None, 7, 7, 1920)        18321984
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1920)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1920)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1920)              7680
# _________________________________________________________________
# dense (Dense)                (None, 128)               245888
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 18,576,580
# Trainable params: 18,343,428
# Non-trainable params: 233,152
# _________________________________________________________________

# %%
# Learning Rate Reducer
learn_control = ReduceLROnPlateau(monitor='val_acc', patience=5,
                                  verbose=1,factor=0.2, min_lr=1e-7)

# Checkpoint
filepath="/content/drive/My Drive/best_IARCR2_DesNet.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %%
history = model.fit_generator(
    train_generator.flow(x_train, y_train, batch_size=BATCH_SIZE),
    steps_per_epoch=x_train.shape[0] / BATCH_SIZE,
    epochs=200,
    validation_data=(x_val, y_val),
    callbacks=[learn_control, checkpoint]
)
# Out:
# WARNING:tensorflow:From <ipython-input-14-b2da819dbb78>:6: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/200
# 9/9 [==============================] - ETA: 0s - loss: 1.8127 - accuracy: 0.2639WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 8s 897ms/step - loss: 1.8127 - accuracy: 0.2639 - val_loss: 1.3725 - val_accuracy: 0.4444
# Epoch 2/200
# 9/9 [==============================] - ETA: 0s - loss: 1.4087 - accuracy: 0.4688WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 533ms/step - loss: 1.4087 - accuracy: 0.4688 - val_loss: 1.2094 - val_accuracy: 0.5556
# Epoch 3/200
# 9/9 [==============================] - ETA: 0s - loss: 1.3214 - accuracy: 0.4306WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 537ms/step - loss: 1.3214 - accuracy: 0.4306 - val_loss: 1.1222 - val_accuracy: 0.5833
# Epoch 4/200
# 9/9 [==============================] - ETA: 0s - loss: 1.3965 - accuracy: 0.4583WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 534ms/step - loss: 1.3965 - accuracy: 0.4583 - val_loss: 1.0430 - val_accuracy: 0.5694
# Epoch 5/200
# 9/9 [==============================] - ETA: 0s - loss: 1.3009 - accuracy: 0.4965WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 530ms/step - loss: 1.3009 - accuracy: 0.4965 - val_loss: 1.0096 - val_accuracy: 0.5694
# Epoch 6/200
# 9/9 [==============================] - ETA: 0s - loss: 1.2086 - accuracy: 0.5556WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 530ms/step - loss: 1.2086 - accuracy: 0.5556 - val_loss: 1.0378 - val_accuracy: 0.5694
# Epoch 7/200
# 9/9 [==============================] - ETA: 0s - loss: 1.1169 - accuracy: 0.5799WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 1.1169 - accuracy: 0.5799 - val_loss: 1.0218 - val_accuracy: 0.5694
# Epoch 8/200
# 9/9 [==============================] - ETA: 0s - loss: 1.0987 - accuracy: 0.5590WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 523ms/step - loss: 1.0987 - accuracy: 0.5590 - val_loss: 0.9609 - val_accuracy: 0.5556
# Epoch 9/200
# 9/9 [==============================] - ETA: 0s - loss: 1.0983 - accuracy: 0.5903WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 1.0983 - accuracy: 0.5903 - val_loss: 0.9764 - val_accuracy: 0.5694
# Epoch 10/200
# 9/9 [==============================] - ETA: 0s - loss: 0.9692 - accuracy: 0.6042WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 524ms/step - loss: 0.9692 - accuracy: 0.6042 - val_loss: 1.0782 - val_accuracy: 0.6250
# Epoch 11/200
# 9/9 [==============================] - ETA: 0s - loss: 0.9532 - accuracy: 0.6285WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 523ms/step - loss: 0.9532 - accuracy: 0.6285 - val_loss: 1.2056 - val_accuracy: 0.6528
# Epoch 12/200
# 9/9 [==============================] - ETA: 0s - loss: 0.8445 - accuracy: 0.6667WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 522ms/step - loss: 0.8445 - accuracy: 0.6667 - val_loss: 0.8546 - val_accuracy: 0.6944
# Epoch 13/200
# 9/9 [==============================] - ETA: 0s - loss: 0.9353 - accuracy: 0.6840WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 524ms/step - loss: 0.9353 - accuracy: 0.6840 - val_loss: 0.5945 - val_accuracy: 0.8333
# Epoch 14/200
# 9/9 [==============================] - ETA: 0s - loss: 0.8757 - accuracy: 0.6458WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.8757 - accuracy: 0.6458 - val_loss: 0.4943 - val_accuracy: 0.8333
# Epoch 15/200
# 9/9 [==============================] - ETA: 0s - loss: 0.8008 - accuracy: 0.7049WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.8008 - accuracy: 0.7049 - val_loss: 0.6071 - val_accuracy: 0.7778
# Epoch 16/200
# 9/9 [==============================] - ETA: 0s - loss: 0.8094 - accuracy: 0.6840WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 528ms/step - loss: 0.8094 - accuracy: 0.6840 - val_loss: 0.5894 - val_accuracy: 0.7917
# Epoch 17/200
# 9/9 [==============================] - ETA: 0s - loss: 0.8176 - accuracy: 0.7083WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.8176 - accuracy: 0.7083 - val_loss: 0.5319 - val_accuracy: 0.8472
# Epoch 18/200
# 9/9 [==============================] - ETA: 0s - loss: 0.7516 - accuracy: 0.7049WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 528ms/step - loss: 0.7516 - accuracy: 0.7049 - val_loss: 0.7990 - val_accuracy: 0.7778
# Epoch 19/200
# 9/9 [==============================] - ETA: 0s - loss: 0.7641 - accuracy: 0.7049WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 529ms/step - loss: 0.7641 - accuracy: 0.7049 - val_loss: 0.6905 - val_accuracy: 0.7500
# Epoch 20/200
# 9/9 [==============================] - ETA: 0s - loss: 0.7489 - accuracy: 0.7153WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.7489 - accuracy: 0.7153 - val_loss: 0.4479 - val_accuracy: 0.8056
# Epoch 21/200
# 9/9 [==============================] - ETA: 0s - loss: 0.6441 - accuracy: 0.7708WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 528ms/step - loss: 0.6441 - accuracy: 0.7708 - val_loss: 0.5269 - val_accuracy: 0.8611
# Epoch 22/200
# 9/9 [==============================] - ETA: 0s - loss: 0.7348 - accuracy: 0.7188WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.7348 - accuracy: 0.7188 - val_loss: 0.5706 - val_accuracy: 0.8194
# Epoch 23/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5843 - accuracy: 0.7674WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 524ms/step - loss: 0.5843 - accuracy: 0.7674 - val_loss: 0.5458 - val_accuracy: 0.8333
# Epoch 24/200
# 9/9 [==============================] - ETA: 0s - loss: 0.6969 - accuracy: 0.7639WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.6969 - accuracy: 0.7639 - val_loss: 0.5182 - val_accuracy: 0.8472
# Epoch 25/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5659 - accuracy: 0.7847WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.5659 - accuracy: 0.7847 - val_loss: 0.6797 - val_accuracy: 0.8333
# Epoch 26/200
# 9/9 [==============================] - ETA: 0s - loss: 0.7174 - accuracy: 0.7535WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.7174 - accuracy: 0.7535 - val_loss: 0.8183 - val_accuracy: 0.7917
# Epoch 27/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5558 - accuracy: 0.7708WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.5558 - accuracy: 0.7708 - val_loss: 0.7810 - val_accuracy: 0.7917
# Epoch 28/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5265 - accuracy: 0.8194WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 524ms/step - loss: 0.5265 - accuracy: 0.8194 - val_loss: 0.6815 - val_accuracy: 0.7778
# Epoch 29/200
# 9/9 [==============================] - ETA: 0s - loss: 0.6306 - accuracy: 0.7639WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.6306 - accuracy: 0.7639 - val_loss: 0.7016 - val_accuracy: 0.8056
# Epoch 30/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5604 - accuracy: 0.8125WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.5604 - accuracy: 0.8125 - val_loss: 0.7665 - val_accuracy: 0.8194
# Epoch 31/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5341 - accuracy: 0.7847WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.5341 - accuracy: 0.7847 - val_loss: 0.8055 - val_accuracy: 0.8056
# Epoch 32/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5957 - accuracy: 0.7569WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.5957 - accuracy: 0.7569 - val_loss: 0.6576 - val_accuracy: 0.8472
# Epoch 33/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5500 - accuracy: 0.8090WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.5500 - accuracy: 0.8090 - val_loss: 0.5520 - val_accuracy: 0.8472
# Epoch 34/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5462 - accuracy: 0.7917WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.5462 - accuracy: 0.7917 - val_loss: 0.6390 - val_accuracy: 0.8611
# Epoch 35/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4986 - accuracy: 0.8194WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 524ms/step - loss: 0.4986 - accuracy: 0.8194 - val_loss: 0.7134 - val_accuracy: 0.8472
# Epoch 36/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4428 - accuracy: 0.8229WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 524ms/step - loss: 0.4428 - accuracy: 0.8229 - val_loss: 0.5473 - val_accuracy: 0.8889
# Epoch 37/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4639 - accuracy: 0.8264WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.4639 - accuracy: 0.8264 - val_loss: 0.4903 - val_accuracy: 0.9306
# Epoch 38/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4798 - accuracy: 0.8160WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.4798 - accuracy: 0.8160 - val_loss: 0.4946 - val_accuracy: 0.9167
# Epoch 39/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4841 - accuracy: 0.8090WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.4841 - accuracy: 0.8090 - val_loss: 0.5060 - val_accuracy: 0.8472
# Epoch 40/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4868 - accuracy: 0.8021WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.4868 - accuracy: 0.8021 - val_loss: 0.5200 - val_accuracy: 0.8750
# Epoch 41/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4250 - accuracy: 0.8264WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.4250 - accuracy: 0.8264 - val_loss: 0.6345 - val_accuracy: 0.8472
# Epoch 42/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4359 - accuracy: 0.8264WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.4359 - accuracy: 0.8264 - val_loss: 0.9646 - val_accuracy: 0.8194
# Epoch 43/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4898 - accuracy: 0.8299WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 523ms/step - loss: 0.4898 - accuracy: 0.8299 - val_loss: 0.8053 - val_accuracy: 0.8333
# Epoch 44/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4387 - accuracy: 0.8438WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.4387 - accuracy: 0.8438 - val_loss: 0.7148 - val_accuracy: 0.8333
# Epoch 45/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4431 - accuracy: 0.8125WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.4431 - accuracy: 0.8125 - val_loss: 0.6369 - val_accuracy: 0.8333
# Epoch 46/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4245 - accuracy: 0.8542WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.4245 - accuracy: 0.8542 - val_loss: 0.7150 - val_accuracy: 0.8472
# Epoch 47/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4422 - accuracy: 0.8403WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 531ms/step - loss: 0.4422 - accuracy: 0.8403 - val_loss: 0.6380 - val_accuracy: 0.8194
# Epoch 48/200
# 9/9 [==============================] - ETA: 0s - loss: 0.5092 - accuracy: 0.8021WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.5092 - accuracy: 0.8021 - val_loss: 0.6514 - val_accuracy: 0.8750
# Epoch 49/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3997 - accuracy: 0.8507WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.3997 - accuracy: 0.8507 - val_loss: 0.7492 - val_accuracy: 0.8611
# Epoch 50/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3159 - accuracy: 0.8681WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 524ms/step - loss: 0.3159 - accuracy: 0.8681 - val_loss: 0.6886 - val_accuracy: 0.8750
# Epoch 51/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3659 - accuracy: 0.8681WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.3659 - accuracy: 0.8681 - val_loss: 0.7024 - val_accuracy: 0.8611
# Epoch 52/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2878 - accuracy: 0.8889WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.2878 - accuracy: 0.8889 - val_loss: 0.6578 - val_accuracy: 0.8611
# Epoch 53/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3989 - accuracy: 0.8472WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.3989 - accuracy: 0.8472 - val_loss: 0.6943 - val_accuracy: 0.8611
# Epoch 54/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3039 - accuracy: 0.8924WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.3039 - accuracy: 0.8924 - val_loss: 1.0843 - val_accuracy: 0.7083
# Epoch 55/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3921 - accuracy: 0.8542WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.3921 - accuracy: 0.8542 - val_loss: 0.9076 - val_accuracy: 0.8056
# Epoch 56/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3223 - accuracy: 0.8646WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 524ms/step - loss: 0.3223 - accuracy: 0.8646 - val_loss: 0.6018 - val_accuracy: 0.8750
# Epoch 57/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3349 - accuracy: 0.8681WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 524ms/step - loss: 0.3349 - accuracy: 0.8681 - val_loss: 0.7100 - val_accuracy: 0.8333
# Epoch 58/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3258 - accuracy: 0.8715WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 530ms/step - loss: 0.3258 - accuracy: 0.8715 - val_loss: 0.7125 - val_accuracy: 0.8056
# Epoch 59/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3270 - accuracy: 0.8715WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.3270 - accuracy: 0.8715 - val_loss: 0.7713 - val_accuracy: 0.8333
# Epoch 60/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2931 - accuracy: 0.8889WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 528ms/step - loss: 0.2931 - accuracy: 0.8889 - val_loss: 0.6523 - val_accuracy: 0.8611
# Epoch 61/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3093 - accuracy: 0.8785WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.3093 - accuracy: 0.8785 - val_loss: 0.8418 - val_accuracy: 0.8611
# Epoch 62/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3525 - accuracy: 0.8750WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.3525 - accuracy: 0.8750 - val_loss: 0.7381 - val_accuracy: 0.8750
# Epoch 63/200
# 9/9 [==============================] - ETA: 0s - loss: 0.4048 - accuracy: 0.8507WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.4048 - accuracy: 0.8507 - val_loss: 0.6341 - val_accuracy: 0.8889
# Epoch 64/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3344 - accuracy: 0.8715WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 524ms/step - loss: 0.3344 - accuracy: 0.8715 - val_loss: 0.5237 - val_accuracy: 0.8889
# Epoch 65/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2858 - accuracy: 0.8854WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.2858 - accuracy: 0.8854 - val_loss: 0.4693 - val_accuracy: 0.8750
# Epoch 66/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3627 - accuracy: 0.8681WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.3627 - accuracy: 0.8681 - val_loss: 0.5196 - val_accuracy: 0.8750
# Epoch 67/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3998 - accuracy: 0.8542WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.3998 - accuracy: 0.8542 - val_loss: 0.5896 - val_accuracy: 0.8333
# Epoch 68/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3350 - accuracy: 0.8646WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.3350 - accuracy: 0.8646 - val_loss: 0.6022 - val_accuracy: 0.8333
# Epoch 69/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3598 - accuracy: 0.8646WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 528ms/step - loss: 0.3598 - accuracy: 0.8646 - val_loss: 0.6942 - val_accuracy: 0.8472
# Epoch 70/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3078 - accuracy: 0.8785WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.3078 - accuracy: 0.8785 - val_loss: 0.5691 - val_accuracy: 0.8750
# Epoch 71/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3228 - accuracy: 0.8646WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.3228 - accuracy: 0.8646 - val_loss: 0.5535 - val_accuracy: 0.8611
# Epoch 72/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2543 - accuracy: 0.8958WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.2543 - accuracy: 0.8958 - val_loss: 0.7471 - val_accuracy: 0.8611
# Epoch 73/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3061 - accuracy: 0.8681WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.3061 - accuracy: 0.8681 - val_loss: 0.6084 - val_accuracy: 0.8611
# Epoch 74/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2699 - accuracy: 0.9097WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.2699 - accuracy: 0.9097 - val_loss: 0.8538 - val_accuracy: 0.8611
# Epoch 75/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3343 - accuracy: 0.8924WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.3343 - accuracy: 0.8924 - val_loss: 0.7499 - val_accuracy: 0.8472
# Epoch 76/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2977 - accuracy: 0.8854WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 528ms/step - loss: 0.2977 - accuracy: 0.8854 - val_loss: 0.7434 - val_accuracy: 0.8472
# Epoch 77/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2434 - accuracy: 0.9097WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.2434 - accuracy: 0.9097 - val_loss: 0.7941 - val_accuracy: 0.8611
# Epoch 78/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2690 - accuracy: 0.9201WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 524ms/step - loss: 0.2690 - accuracy: 0.9201 - val_loss: 0.8406 - val_accuracy: 0.8333
# Epoch 79/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3266 - accuracy: 0.8646WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.3266 - accuracy: 0.8646 - val_loss: 0.8412 - val_accuracy: 0.8750
# Epoch 80/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3668 - accuracy: 0.8507WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.3668 - accuracy: 0.8507 - val_loss: 0.8278 - val_accuracy: 0.8611
# Epoch 81/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2359 - accuracy: 0.9062WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.2359 - accuracy: 0.9062 - val_loss: 0.6738 - val_accuracy: 0.8750
# Epoch 82/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2322 - accuracy: 0.9167WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 528ms/step - loss: 0.2322 - accuracy: 0.9167 - val_loss: 0.6940 - val_accuracy: 0.8333
# Epoch 83/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2311 - accuracy: 0.8993WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 524ms/step - loss: 0.2311 - accuracy: 0.8993 - val_loss: 0.6114 - val_accuracy: 0.8750
# Epoch 84/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3182 - accuracy: 0.8854WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 528ms/step - loss: 0.3182 - accuracy: 0.8854 - val_loss: 0.6422 - val_accuracy: 0.8750
# Epoch 85/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3677 - accuracy: 0.8542WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.3677 - accuracy: 0.8542 - val_loss: 0.5645 - val_accuracy: 0.8750
# Epoch 86/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2693 - accuracy: 0.8993WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 524ms/step - loss: 0.2693 - accuracy: 0.8993 - val_loss: 0.5523 - val_accuracy: 0.9028
# Epoch 87/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3823 - accuracy: 0.8681WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.3823 - accuracy: 0.8681 - val_loss: 0.7653 - val_accuracy: 0.8889
# Epoch 88/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2536 - accuracy: 0.8958WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.2536 - accuracy: 0.8958 - val_loss: 0.6912 - val_accuracy: 0.9028
# Epoch 89/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3151 - accuracy: 0.8854WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 523ms/step - loss: 0.3151 - accuracy: 0.8854 - val_loss: 0.6730 - val_accuracy: 0.8889
# Epoch 90/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3052 - accuracy: 0.8993WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 528ms/step - loss: 0.3052 - accuracy: 0.8993 - val_loss: 0.6146 - val_accuracy: 0.8889
# Epoch 91/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2753 - accuracy: 0.8993WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.2753 - accuracy: 0.8993 - val_loss: 0.6400 - val_accuracy: 0.9167
# Epoch 92/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2447 - accuracy: 0.9062WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.2447 - accuracy: 0.9062 - val_loss: 0.7365 - val_accuracy: 0.9028
# Epoch 93/200
# 9/9 [==============================] - ETA: 0s - loss: 0.3022 - accuracy: 0.8854WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.3022 - accuracy: 0.8854 - val_loss: 0.8431 - val_accuracy: 0.8611
# Epoch 94/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2434 - accuracy: 0.8993WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 528ms/step - loss: 0.2434 - accuracy: 0.8993 - val_loss: 0.7515 - val_accuracy: 0.8889
# Epoch 95/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2777 - accuracy: 0.8924WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.2777 - accuracy: 0.8924 - val_loss: 0.6546 - val_accuracy: 0.8750
# Epoch 96/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2240 - accuracy: 0.9097WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.2240 - accuracy: 0.9097 - val_loss: 0.5606 - val_accuracy: 0.8750
# Epoch 97/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2255 - accuracy: 0.9132WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.2255 - accuracy: 0.9132 - val_loss: 0.6301 - val_accuracy: 0.8333
# Epoch 98/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2333 - accuracy: 0.9167WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 528ms/step - loss: 0.2333 - accuracy: 0.9167 - val_loss: 0.7631 - val_accuracy: 0.7917
# Epoch 99/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2535 - accuracy: 0.9201WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.2535 - accuracy: 0.9201 - val_loss: 0.7796 - val_accuracy: 0.8333
# Epoch 100/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2419 - accuracy: 0.9167WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.2419 - accuracy: 0.9167 - val_loss: 1.1266 - val_accuracy: 0.7778
# Epoch 101/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2622 - accuracy: 0.9097WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 528ms/step - loss: 0.2622 - accuracy: 0.9097 - val_loss: 1.2139 - val_accuracy: 0.7639
# Epoch 102/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2737 - accuracy: 0.8993WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 524ms/step - loss: 0.2737 - accuracy: 0.8993 - val_loss: 1.1393 - val_accuracy: 0.8194
# Epoch 103/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2594 - accuracy: 0.8958WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.2594 - accuracy: 0.8958 - val_loss: 0.7100 - val_accuracy: 0.8750
# Epoch 104/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2399 - accuracy: 0.8924WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.2399 - accuracy: 0.8924 - val_loss: 0.4618 - val_accuracy: 0.9167
# Epoch 105/200
# ...
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.2498 - accuracy: 0.9097 - val_loss: 0.8997 - val_accuracy: 0.8194
# Epoch 167/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2215 - accuracy: 0.9306WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.2215 - accuracy: 0.9306 - val_loss: 0.8043 - val_accuracy: 0.8333
# Epoch 168/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1357 - accuracy: 0.9514WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.1357 - accuracy: 0.9514 - val_loss: 0.6617 - val_accuracy: 0.8611
# Epoch 169/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1805 - accuracy: 0.9306WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.1805 - accuracy: 0.9306 - val_loss: 0.5028 - val_accuracy: 0.9028
# Epoch 170/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1166 - accuracy: 0.9618WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 528ms/step - loss: 0.1166 - accuracy: 0.9618 - val_loss: 0.5740 - val_accuracy: 0.8472
# Epoch 171/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2030 - accuracy: 0.9306WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.2030 - accuracy: 0.9306 - val_loss: 0.9860 - val_accuracy: 0.7917
# Epoch 172/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2112 - accuracy: 0.9410WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 529ms/step - loss: 0.2112 - accuracy: 0.9410 - val_loss: 0.7232 - val_accuracy: 0.8472
# Epoch 173/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2098 - accuracy: 0.9132WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 528ms/step - loss: 0.2098 - accuracy: 0.9132 - val_loss: 0.5459 - val_accuracy: 0.8750
# Epoch 174/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1972 - accuracy: 0.9340WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.1972 - accuracy: 0.9340 - val_loss: 0.4968 - val_accuracy: 0.8889
# Epoch 175/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2428 - accuracy: 0.9097WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 530ms/step - loss: 0.2428 - accuracy: 0.9097 - val_loss: 0.5192 - val_accuracy: 0.8750
# Epoch 176/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1620 - accuracy: 0.9236WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 528ms/step - loss: 0.1620 - accuracy: 0.9236 - val_loss: 0.4487 - val_accuracy: 0.8750
# Epoch 177/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1805 - accuracy: 0.9444WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 530ms/step - loss: 0.1805 - accuracy: 0.9444 - val_loss: 0.5123 - val_accuracy: 0.8611
# Epoch 178/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2486 - accuracy: 0.9062WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 523ms/step - loss: 0.2486 - accuracy: 0.9062 - val_loss: 0.5789 - val_accuracy: 0.9028
# Epoch 179/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1750 - accuracy: 0.9236WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 528ms/step - loss: 0.1750 - accuracy: 0.9236 - val_loss: 0.6304 - val_accuracy: 0.8889
# Epoch 180/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1441 - accuracy: 0.9583WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 525ms/step - loss: 0.1441 - accuracy: 0.9583 - val_loss: 0.5374 - val_accuracy: 0.9028
# Epoch 181/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2076 - accuracy: 0.9236WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.2076 - accuracy: 0.9236 - val_loss: 0.5246 - val_accuracy: 0.9028
# Epoch 182/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2012 - accuracy: 0.9201WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.2012 - accuracy: 0.9201 - val_loss: 0.4651 - val_accuracy: 0.8889
# Epoch 183/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2391 - accuracy: 0.9271WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 529ms/step - loss: 0.2391 - accuracy: 0.9271 - val_loss: 0.4165 - val_accuracy: 0.9167
# Epoch 184/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1482 - accuracy: 0.9479WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.1482 - accuracy: 0.9479 - val_loss: 0.4394 - val_accuracy: 0.8750
# Epoch 185/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1912 - accuracy: 0.9410WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.1912 - accuracy: 0.9410 - val_loss: 0.4358 - val_accuracy: 0.9167
# Epoch 186/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1576 - accuracy: 0.9306WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 524ms/step - loss: 0.1576 - accuracy: 0.9306 - val_loss: 0.4053 - val_accuracy: 0.9167
# Epoch 187/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2395 - accuracy: 0.9201WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 529ms/step - loss: 0.2395 - accuracy: 0.9201 - val_loss: 0.4522 - val_accuracy: 0.8889
# Epoch 188/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1705 - accuracy: 0.9479WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.1705 - accuracy: 0.9479 - val_loss: 0.4563 - val_accuracy: 0.8889
# Epoch 189/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1532 - accuracy: 0.9514WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.1532 - accuracy: 0.9514 - val_loss: 0.3676 - val_accuracy: 0.8889
# Epoch 190/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1936 - accuracy: 0.9340WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 529ms/step - loss: 0.1936 - accuracy: 0.9340 - val_loss: 0.4334 - val_accuracy: 0.9028
# Epoch 191/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1477 - accuracy: 0.9444WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 530ms/step - loss: 0.1477 - accuracy: 0.9444 - val_loss: 0.4418 - val_accuracy: 0.8889
# Epoch 192/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1145 - accuracy: 0.9514WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 528ms/step - loss: 0.1145 - accuracy: 0.9514 - val_loss: 0.4767 - val_accuracy: 0.8750
# Epoch 193/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1989 - accuracy: 0.9167WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 529ms/step - loss: 0.1989 - accuracy: 0.9167 - val_loss: 0.5044 - val_accuracy: 0.8889
# Epoch 194/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1528 - accuracy: 0.9549WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.1528 - accuracy: 0.9549 - val_loss: 0.5691 - val_accuracy: 0.8611
# Epoch 195/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2118 - accuracy: 0.9167WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 528ms/step - loss: 0.2118 - accuracy: 0.9167 - val_loss: 0.5682 - val_accuracy: 0.8889
# Epoch 196/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1820 - accuracy: 0.9410WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 530ms/step - loss: 0.1820 - accuracy: 0.9410 - val_loss: 0.6133 - val_accuracy: 0.9028
# Epoch 197/200
# 9/9 [==============================] - ETA: 0s - loss: 0.2050 - accuracy: 0.9306WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 527ms/step - loss: 0.2050 - accuracy: 0.9306 - val_loss: 0.6773 - val_accuracy: 0.8750
# Epoch 198/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1739 - accuracy: 0.9340WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 528ms/step - loss: 0.1739 - accuracy: 0.9340 - val_loss: 0.6395 - val_accuracy: 0.8889
# Epoch 199/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1624 - accuracy: 0.9306WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 526ms/step - loss: 0.1624 - accuracy: 0.9306 - val_loss: 0.5248 - val_accuracy: 0.8889
# Epoch 200/200
# 9/9 [==============================] - ETA: 0s - loss: 0.1660 - accuracy: 0.9375WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 9/9 [==============================] - 5s 524ms/step - loss: 0.1660 - accuracy: 0.9375 - val_loss: 0.5223 - val_accuracy: 0.9028

# %%
Y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))

cm_plot_label =['Benign', 'InSitu', 'Invasive', 'Normal']
plot_confusion_matrix(cm, cm_plot_label, title ='Multiclass Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[10  0  0  0]
#  [ 0  8  1  1]
#  [ 1  0  9  0]
#  [ 1  0  1  8]]

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('DenseNet Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,201))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.grid()
ax1.set_xticks(np.arange(1, 201, 15))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.grid()
ax2.set_xticks(np.arange(1, 201, 15))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
pred=model.predict(X_test)
Y_pred = np.argmax(pred, 1)
y_test=np.argmax(Y_test,1)
from sklearn.metrics import classification_report, confusion_matrix
print('Classification Report')
target_names = ['Benign', 'InSitu', 'Invasive', 'Normal']
print(classification_report(y_test, Y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#       Benign       0.83      1.00      0.91        10
#       InSitu       1.00      0.80      0.89        10
#     Invasive       0.82      0.90      0.86        10
#       Normal       0.89      0.80      0.84        10
#
#     accuracy                           0.88        40
#    macro avg       0.89      0.88      0.87        40
# weighted avg       0.89      0.88      0.87        40

# %%
pred=model.predict(X_test)
Y_pred = np.argmax(pred, 1)
Y_test=np.argmax(Y_test,1)

# %%
import numpy as np
from sklearn import metrics
fpr, tpr, thresholds = metrics.roc_curve(Y_test, Y_pred, pos_label=2)
auc=metrics.auc(fpr, tpr)
auc
# Out:
# 0.6183333333333333

# %%
plt.plot([0, 1], [0, 1], 'r--')
plt.plot(fpr, tpr, label='AUC = {:.3f}'.format(auc))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
#plt.savefig(ROC_PLOT_FILE, bbox_inches='tight')
plt.close()
