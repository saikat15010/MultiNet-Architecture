# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
import json
import math
import os

import cv2
from PIL import Image
import numpy as np
from keras import layers
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg16 import VGG16
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D, Average, Input, Concatenate, GlobalMaxPooling2D,BatchNormalization
from keras.applications import ResNet50,MobileNet, DenseNet201, InceptionV3, NASNetLarge, InceptionResNetV2, NASNetMobile
from keras.applications.xception import Xception
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.optimizers import Adam
from keras.models import Model
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools


# %matplotlib inline

# %%
#Transfer 'jpg' images to an array IMG
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".png":
            img = read(PATH)
           
            img = cv2.resize(img, (RESIZE,RESIZE))
           
            IMG.append(np.array(img))
    return IMG

# %%
benign_train = np.array(Dataset_loader('/content/drive/My Drive/BreakHish Final Dataset/train/benign',224))
malign_train = np.array(Dataset_loader('/content/drive/My Drive/BreakHish Final Dataset/train/malignant',224))
benign_test = np.array(Dataset_loader('/content/drive/My Drive/BreakHish Final Dataset/test/benign',224))
malign_test = np.array(Dataset_loader('/content/drive/My Drive/BreakHish Final Dataset/test/malignant',224))
# Out:
# 100%|██████████| 2405/2405 [22:14<00:00,  1.80it/s]
# 100%|██████████| 5348/5348 [46:31<00:00,  1.92it/s]
# 100%|██████████| 75/75 [00:42<00:00,  1.76it/s]
# 100%|██████████| 85/85 [00:48<00:00,  1.74it/s]

# %%
# Create labels\\
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))

# %%
# Merge data 
X_train = np.concatenate((benign_train, malign_train), axis = 0)
Y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
X_test = np.concatenate((benign_test, malign_test), axis = 0)
Y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)

# %%
# Shuffle train data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = Y_train[s]

# Shuffle test data
s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = Y_test[s]

# %%
# To categorical
Y_train = to_categorical(Y_train, num_classes= 2)
Y_test = to_categorical(Y_test, num_classes= 2)

# %%
x_train, x_val, y_train, y_val = train_test_split(
    X_train, Y_train, 
    test_size=0.2, 
    random_state=11
)

# %%
# # Display first 15 images of moles, and how they are classified
w=60
h=40
fig=plt.figure(figsize=(10,10))
columns = 4
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(Y_train[i]) == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(x_train[i], interpolation='nearest')
plt.show()

# %%
BATCH_SIZE = 32

# Using original generator
train_generator = ImageDataGenerator(
        zoom_range=2,  # set range for random zoom
        rotation_range = 90,
        shear_range = 0.5,
        width_shift_range=0.4,
        height_shift_range=0.4,
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True  # randomly flip images
    )

# %%
IMAGE_SIZE=224
# Model
input_shape = (IMAGE_SIZE, IMAGE_SIZE, 3)
inputs = Input(input_shape)
 
#dennet   = DenseNet201(include_top=False, input_shape=input_shape)(inputs)
nas      = NASNetMobile(include_top=False, input_shape=input_shape)(inputs)
#vgg      = VGG16(include_top=False, input_shape=input_shape)(inputs)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19996672/19993432 [==============================] - 0s 0us/step

# %%
outputs = GlobalAveragePooling2D()(nas)
outputs = Dropout(0.4)(outputs)
outputs = BatchNormalization()(outputs) 
outputs = Dense(128,activation='relu')(outputs) 
outputs = Dropout(0.2)(outputs)
outputs = BatchNormalization()(outputs) 
outputs = Dense(2, activation='softmax')(outputs)

model = Model(inputs, outputs)
model.compile(optimizer=Adam(lr=0.0001, decay=0.00001),
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# NASNet (Functional)          (None, 7, 7, 1056)        4269716
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1056)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1056)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1056)              4224
# _________________________________________________________________
# dense (Dense)                (None, 128)               135296
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 4,410,006
# Trainable params: 4,370,900
# Non-trainable params: 39,106
# _________________________________________________________________

# %%
# Learning Rate Reducer
learn_control = ReduceLROnPlateau(monitor='val_acc', patience=5,
                                  verbose=1,factor=0.2, min_lr=1e-7)

# Checkpoint
filepath="/content/drive/My Drive/best_nas.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %%
history = model.fit_generator(
    train_generator.flow(x_train, y_train, batch_size=BATCH_SIZE),
    steps_per_epoch=x_train.shape[0] / BATCH_SIZE,
    epochs=50,
    validation_data=(x_val, y_val),
    callbacks=[learn_control, checkpoint]
)
# Out:
# WARNING:tensorflow:From <ipython-input-16-6994e6891fd9>:6: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 194/193 [==============================] - ETA: 0s - loss: 0.7680 - accuracy: 0.6493WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 97s 501ms/step - loss: 0.7680 - accuracy: 0.6493 - val_loss: 0.9152 - val_accuracy: 0.6505
# Epoch 2/50
# 194/193 [==============================] - ETA: 0s - loss: 0.4794 - accuracy: 0.8033WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 95s 492ms/step - loss: 0.4794 - accuracy: 0.8033 - val_loss: 0.8481 - val_accuracy: 0.6867
# Epoch 3/50
# 194/193 [==============================] - ETA: 0s - loss: 0.3922 - accuracy: 0.8510WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 96s 497ms/step - loss: 0.3922 - accuracy: 0.8510 - val_loss: 0.7871 - val_accuracy: 0.6667
# Epoch 4/50
# 194/193 [==============================] - ETA: 0s - loss: 0.3345 - accuracy: 0.8744WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 96s 497ms/step - loss: 0.3345 - accuracy: 0.8744 - val_loss: 0.8404 - val_accuracy: 0.5938
# Epoch 5/50
# 194/193 [==============================] - ETA: 0s - loss: 0.3155 - accuracy: 0.8808WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 96s 495ms/step - loss: 0.3155 - accuracy: 0.8808 - val_loss: 1.3154 - val_accuracy: 0.4965
# Epoch 6/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2804 - accuracy: 0.8947WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 95s 489ms/step - loss: 0.2804 - accuracy: 0.8947 - val_loss: 1.6537 - val_accuracy: 0.3765
# Epoch 7/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2657 - accuracy: 0.8952WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 95s 489ms/step - loss: 0.2657 - accuracy: 0.8952 - val_loss: 2.2266 - val_accuracy: 0.3507
# Epoch 8/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2501 - accuracy: 0.9037WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 94s 487ms/step - loss: 0.2501 - accuracy: 0.9037 - val_loss: 2.3704 - val_accuracy: 0.3475
# Epoch 9/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2423 - accuracy: 0.9070WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 94s 486ms/step - loss: 0.2423 - accuracy: 0.9070 - val_loss: 1.4995 - val_accuracy: 0.4223
# Epoch 10/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2049 - accuracy: 0.9208WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 94s 485ms/step - loss: 0.2049 - accuracy: 0.9208 - val_loss: 1.8987 - val_accuracy: 0.4230
# Epoch 11/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2241 - accuracy: 0.9095WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 94s 484ms/step - loss: 0.2241 - accuracy: 0.9095 - val_loss: 2.0363 - val_accuracy: 0.4223
# Epoch 12/50
# 194/193 [==============================] - ETA: 0s - loss: 0.2113 - accuracy: 0.9173WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 94s 484ms/step - loss: 0.2113 - accuracy: 0.9173 - val_loss: 3.9814 - val_accuracy: 0.3817
# Epoch 13/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1990 - accuracy: 0.9242WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 94s 485ms/step - loss: 0.1990 - accuracy: 0.9242 - val_loss: 1.2069 - val_accuracy: 0.5777
# Epoch 14/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1861 - accuracy: 0.9250WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 94s 485ms/step - loss: 0.1861 - accuracy: 0.9250 - val_loss: 1.7519 - val_accuracy: 0.5738
# Epoch 15/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1862 - accuracy: 0.9300WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 96s 495ms/step - loss: 0.1862 - accuracy: 0.9300 - val_loss: 3.2868 - val_accuracy: 0.4462
# Epoch 16/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1786 - accuracy: 0.9241WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 96s 495ms/step - loss: 0.1786 - accuracy: 0.9241 - val_loss: 2.9428 - val_accuracy: 0.5571
# Epoch 17/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1832 - accuracy: 0.9308WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 96s 496ms/step - loss: 0.1832 - accuracy: 0.9308 - val_loss: 3.7407 - val_accuracy: 0.5229
# Epoch 18/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1633 - accuracy: 0.9384WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 97s 501ms/step - loss: 0.1633 - accuracy: 0.9384 - val_loss: 2.9311 - val_accuracy: 0.5996
# Epoch 19/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1664 - accuracy: 0.9363WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 97s 502ms/step - loss: 0.1664 - accuracy: 0.9363 - val_loss: 4.4341 - val_accuracy: 0.4894
# Epoch 20/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1688 - accuracy: 0.9310WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 98s 505ms/step - loss: 0.1688 - accuracy: 0.9310 - val_loss: 4.3623 - val_accuracy: 0.5351
# Epoch 21/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1608 - accuracy: 0.9379WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 98s 507ms/step - loss: 0.1608 - accuracy: 0.9379 - val_loss: 1.2983 - val_accuracy: 0.7466
# Epoch 22/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1443 - accuracy: 0.9449WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 98s 504ms/step - loss: 0.1443 - accuracy: 0.9449 - val_loss: 0.9275 - val_accuracy: 0.7834
# Epoch 23/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1453 - accuracy: 0.9460WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 98s 507ms/step - loss: 0.1453 - accuracy: 0.9460 - val_loss: 0.6815 - val_accuracy: 0.7982
# Epoch 24/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1748 - accuracy: 0.9358WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 97s 501ms/step - loss: 0.1748 - accuracy: 0.9358 - val_loss: 1.0778 - val_accuracy: 0.8169
# Epoch 25/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1429 - accuracy: 0.9453WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 98s 507ms/step - loss: 0.1429 - accuracy: 0.9453 - val_loss: 0.9792 - val_accuracy: 0.7885
# Epoch 26/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1486 - accuracy: 0.9421WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 98s 505ms/step - loss: 0.1486 - accuracy: 0.9421 - val_loss: 0.4488 - val_accuracy: 0.8556
# Epoch 27/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1294 - accuracy: 0.9494WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 99s 509ms/step - loss: 0.1294 - accuracy: 0.9494 - val_loss: 0.5285 - val_accuracy: 0.8485
# Epoch 28/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1343 - accuracy: 0.9486WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 99s 508ms/step - loss: 0.1343 - accuracy: 0.9486 - val_loss: 0.5736 - val_accuracy: 0.8736
# Epoch 29/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1365 - accuracy: 0.9515WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 99s 509ms/step - loss: 0.1365 - accuracy: 0.9515 - val_loss: 0.6806 - val_accuracy: 0.8807
# Epoch 30/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1230 - accuracy: 0.9495WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 99s 510ms/step - loss: 0.1230 - accuracy: 0.9495 - val_loss: 0.4051 - val_accuracy: 0.9026
# Epoch 31/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1277 - accuracy: 0.9528WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 98s 507ms/step - loss: 0.1277 - accuracy: 0.9528 - val_loss: 0.4854 - val_accuracy: 0.8994
# Epoch 32/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1210 - accuracy: 0.9536WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 97s 499ms/step - loss: 0.1210 - accuracy: 0.9536 - val_loss: 0.5633 - val_accuracy: 0.8698
# Epoch 33/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1154 - accuracy: 0.9547WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 98s 505ms/step - loss: 0.1154 - accuracy: 0.9547 - val_loss: 0.3709 - val_accuracy: 0.9046
# Epoch 34/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1140 - accuracy: 0.9558WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 98s 507ms/step - loss: 0.1140 - accuracy: 0.9558 - val_loss: 0.2317 - val_accuracy: 0.9342
# Epoch 35/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1234 - accuracy: 0.9542WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 99s 509ms/step - loss: 0.1234 - accuracy: 0.9542 - val_loss: 0.3531 - val_accuracy: 0.9123
# Epoch 36/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1150 - accuracy: 0.9611WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 96s 494ms/step - loss: 0.1150 - accuracy: 0.9611 - val_loss: 0.2616 - val_accuracy: 0.9329
# Epoch 37/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1072 - accuracy: 0.9594WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 94s 484ms/step - loss: 0.1072 - accuracy: 0.9594 - val_loss: 0.2105 - val_accuracy: 0.9407
# Epoch 38/50
# 194/193 [==============================] - ETA: 0s - loss: 0.0910 - accuracy: 0.9671WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 94s 484ms/step - loss: 0.0910 - accuracy: 0.9671 - val_loss: 0.2824 - val_accuracy: 0.9162
# Epoch 39/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1115 - accuracy: 0.9584WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 94s 485ms/step - loss: 0.1115 - accuracy: 0.9584 - val_loss: 0.3973 - val_accuracy: 0.9175
# Epoch 40/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1034 - accuracy: 0.9594WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 94s 482ms/step - loss: 0.1034 - accuracy: 0.9594 - val_loss: 0.2223 - val_accuracy: 0.9523
# Epoch 41/50
# 194/193 [==============================] - ETA: 0s - loss: 0.0960 - accuracy: 0.9634WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 93s 481ms/step - loss: 0.0960 - accuracy: 0.9634 - val_loss: 0.1226 - val_accuracy: 0.9600
# Epoch 42/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1028 - accuracy: 0.9600WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 94s 482ms/step - loss: 0.1028 - accuracy: 0.9600 - val_loss: 0.1496 - val_accuracy: 0.9581
# Epoch 43/50
# 194/193 [==============================] - ETA: 0s - loss: 0.0932 - accuracy: 0.9642WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 94s 483ms/step - loss: 0.0932 - accuracy: 0.9642 - val_loss: 0.1363 - val_accuracy: 0.9536
# Epoch 44/50
# 194/193 [==============================] - ETA: 0s - loss: 0.0892 - accuracy: 0.9673WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 93s 482ms/step - loss: 0.0892 - accuracy: 0.9673 - val_loss: 0.1440 - val_accuracy: 0.9620
# Epoch 45/50
# 194/193 [==============================] - ETA: 0s - loss: 0.0841 - accuracy: 0.9673WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 94s 484ms/step - loss: 0.0841 - accuracy: 0.9673 - val_loss: 0.0977 - val_accuracy: 0.9691
# Epoch 46/50
# 194/193 [==============================] - ETA: 0s - loss: 0.1042 - accuracy: 0.9636WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 94s 484ms/step - loss: 0.1042 - accuracy: 0.9636 - val_loss: 0.2276 - val_accuracy: 0.9317
# Epoch 47/50
# 194/193 [==============================] - ETA: 0s - loss: 0.0813 - accuracy: 0.9711WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 94s 484ms/step - loss: 0.0813 - accuracy: 0.9711 - val_loss: 0.2025 - val_accuracy: 0.9336
# Epoch 48/50
# 194/193 [==============================] - ETA: 0s - loss: 0.0984 - accuracy: 0.9613WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 94s 487ms/step - loss: 0.0984 - accuracy: 0.9613 - val_loss: 0.1052 - val_accuracy: 0.9678
# Epoch 49/50
# 194/193 [==============================] - ETA: 0s - loss: 0.0942 - accuracy: 0.9663WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 94s 486ms/step - loss: 0.0942 - accuracy: 0.9663 - val_loss: 0.1582 - val_accuracy: 0.9458
# Epoch 50/50
# 194/193 [==============================] - ETA: 0s - loss: 0.0868 - accuracy: 0.9671WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 194/193 [==============================] - 94s 485ms/step - loss: 0.0868 - accuracy: 0.9671 - val_loss: 0.1252 - val_accuracy: 0.9594

# %%
Y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))

cm_plot_label =['Benign', 'Malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Benign vs Malignant')
# Out:
# Confusion matrix, without normalization
# [[66  9]
#  [ 2 83]]

# %%
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
roc_log = roc_auc_score(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))
false_positive_rate, true_positive_rate, threshold = roc_curve(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))
area_under_curve = auc(false_positive_rate, true_positive_rate)

plt.plot([0, 1], [0, 1], 'r--')
plt.plot(false_positive_rate, true_positive_rate, label='AUC = {:.3f}'.format(area_under_curve))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
#plt.savefig(ROC_PLOT_FILE, bbox_inches='tight')
plt.close()

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('NasNetMobile Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,51))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.grid()
ax1.set_xticks(np.arange(1, 51, 4))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.grid()
ax2.set_xticks(np.arange(1, 51, 4))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
pred=model.predict(X_test)
Y_pred = np.argmax(pred, 1)
y_test=np.argmax(Y_test,1)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print('Classification Report')
target_names = ['Benign', 'Malignant']
print(classification_report(y_test, Y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#       Benign       0.97      0.88      0.92        75
#    Malignant       0.90      0.98      0.94        85
#
#     accuracy                           0.93       160
#    macro avg       0.94      0.93      0.93       160
# weighted avg       0.93      0.93      0.93       160
